# %% [markdown]
# # Cryptanalyse

# %% [markdown]
# Note : Ces exemples sont proposés à des fins éducatives uniquement. Il ne sont pas destinés à être utilisés à des fins illégales. Les attaques de mots de passe ne doivent être effectuées qu'avec la permission explicite du propriétaire du système qui est attaqué.

# %% [markdown]
# ## Attaque par force brute

# %% [markdown]
# En cryptographie, une [attaque par force](https://fr.wikipedia.org/wiki/Attaque_par_force_brute) brute consiste en un attaquant soumettant de nombreux mots de passe ou phrases secrètes dans l'espoir de deviner correctement à la fin. L'attaquant vérifie systématiquement tous les mots de passe et phrases secrètes possibles jusqu'à ce qu'il trouve le bon.
#
# **Que devez-vous faire 💪?**
#
# _Écrivez un programme Python qui simule une attaque par force brute sur un mot de passe en essayant toutes les combinaisons de caractères possibles._

# %%
#Quels sont les différentes étapes du programme à écrire ?
...

# %%
#Créer votre function permettant de deviner un mot de passe avec cette méthode
...

# %%
#Une fois effectué, demandez de l'aide pour obtenir des libraries performantes pour cette tâche et intégrez les dans votre programme
...

# %% [markdown]
# Remarque : cette méthode de craquage de mots de passe peut être très longue, en particulier pour les mots de passe plus longs ou si l'ensemble des caractères possibles est grand. En pratique, les attaquants utilisent souvent des méthodes plus sophistiquées telles que les attaques par dictionnaire

# %% [markdown]
# ## Attaque par dictionaire

# %% [markdown]
# L'[attaque par dictionnaire](https://fr.wikipedia.org/wiki/Attaque_par_dictionnaire) est une méthode utilisée en cryptanalyse pour trouver un mot de passe ou une clé. Elle consiste à tester une série de mots de passe potentiels, les uns à la suite des autres, en espérant que le mot de passe utilisé pour le chiffrement soit contenu dans le dictionnaire. Si ce n'est pas le cas, l'attaque échouera.
#
# **Que devez-vous faire 💪?**
#
# _Écrivez un programme Python qui simule une attaque par dictionnaire sur un mot de passe en essayant une liste de mots de passe couramment utilisés ainsi que leurs variations._

# %%
#Quels sont les différentes étapes du programme à écrire ?
...

# %%
#Créer votre function permettant de deviner un mot de passe avec cette méthode
...

# %%
#Une fois effectué, demandez de l'aide pour obtenir des libraries performantes pour cette tâche et intégrez les dans votre programme
...

# %% [markdown]
# Est-il pertinent de combiner les 2 méthodes 🎉 ?

# %% [markdown]
# # Bonus : scraper un site web

# %% [markdown]
# **Que devez-vous faire 💪?**
#
# Vous êtes à la tête d'une agence de cybersecurité. Vous souhaitez inviter vos clients à une conférence et devez récupérer leur nom sur ce `[site](https://quotes.toscrape.com/.
# Écrivez un programme qui permet de récupérer tous les) auteurs !!!

# %%
#Quels sont les différentes étapes du programme à écrire ?
...

# %%
#Créer votre function permettant de scraper les auteurs sur ce site
...
